# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
print(cities)
# Out:
# Number of cities in the list: 619
# ['busselton', 'hobart', 'belushya guba', 'jamestown', 'tasiilaq', 'nome', 'bowen', 'mercedes', 'lebu', 'punta arenas', 'lazarev', 'hilo', 'arraial do cabo', 'bengkulu', 'provideniya', 'avera', 'bolgar', 'mataura', 'bethanien', 'ushuaia', 'taolanaro', 'karratha', 'si sa ket', 'atuona', 'cape town', 'formosa', 'chokurdakh', 'petropavlovsk-kamchatskiy', 'grindavik', 'yellowknife', 'te anau', 'bluff', 'bethel', 'troitsko-pechorsk', 'diapaga', 'yulara', 'okhotsk', 'doka', 'albany', 'hasaki', 'cap malheureux', 'tiksi', 'nanortalik', 'asfi', 'thompson', 'avarua', 'ostersund', 'mys shmidta', 'urumqi', 'hermanus', 'ribeira grande', 'alekseyevsk', 'saleaula', 'torbay', 'castro', 'kavieng', 'okha', 'iqaluit', 'nikolskoye', 'bauchi', 'cherskiy', 'saskylakh', 'dikson', 'gasa', 'marsh harbour', 'ponta delgada', 'calvillo', 'adjumani', 'cidreira', 'rikitea', 'vila velha', 'vaini', 'new norfolk', 'butaritari', 'ntoum', 'arlit', 'halalo', 'ponta do sol', 'shevchenkove', 'kapaa', 'ambon', 'ksenyevka', 'mul', 'brigantine', 'queenstown', 'kaitangata', 'georgetown', 'chiredzi', 'broome', 'aykhal', 'bolungarvik', 'east london', 'tumannyy', 'mayumba', 'bambous virieux', 'zhigansk', 'saquarema', 'bandarbeyla', 'concord', 'santa rosa', 'xining', 'kitgum', 'kodiak', 'constitucion', 'olinda', 'aksay', 'poum', 'egvekinot', 'karaul', 'puerto ayora', 'kununurra', 'strai', 'northam', 'saldanha', 'cuamba', 'sao jose de ribamar', 'san jose', 'mehamn', 'san rafael del sur', 'sitka', 'katsuura', 'mujiayingzi', 'comodoro rivadavia', 'mar del plata', 'bull savanna', 'mahebourg', 'saurimo', 'fort nelson', 'mahibadhoo', 'barrow', 'olafsvik', 'borogontsy', 'hit', 'vestmannaeyjar', 'aybak', 'qaanaaq', 'calamar', 'narsaq', 'jefferson city', 'tumut', 'lagoa', 'seoul', 'baoding', 'gat', 'bredasdorp', 'serenje', 'that phanom', 'illoqqortoormiut', 'marcona', 'port lincoln', 'tungkang', 'tigil', 'alta floresta', 'chuy', 'karymskoye', 'port blair', 'norman wells', 'carnarvon', 'rocha', 'tars', 'moralillo', 'ashland', 'surt', 'hofn', 'phalaborwa', 'hithadhoo', 'bargi', 'nuuk', 'wanning', 'umm durman', 'fasa', 'chumphon', 'san luis', 'port macquarie', 'tromso', 'mackay', 'amderma', 'vysokogornyy', 'jambi', 'tabiauea', 'agua branca', 'khatanga', 'port alfred', 'moron', 'bonavista', 'jalu', 'alibag', 'champerico', 'igurusi', 'naze', 'sekoma', 'moindou', 'atasu', 'quatre cocos', 'vardo', 'keshan', 'namibe', 'barentsburg', 'mayo', 'lagos', 'ondjiva', 'corralillo', 'oriximina', 'santa rosalia', 'skagastrond', 'verkhnevilyuysk', 'kahului', 'vao', 'hohhot', 'ulladulla', 'aksu', 'birecik', 'komsomolskiy', 'sinop', 'lolua', 'hamilton', 'xai-xai', 'dno', 'borovskoy', 'codrington', 'salalah', 'kenai', 'grand river south east', 'san patricio', 'flinders', 'izhma', 'berdyuzhye', 'oranjemund', 'kudahuvadhoo', 'kaeo', 'cabo san lucas', 'sola', 'westport', 'itaueira', 'saint-philippe', 'brandfort', 'ostrovnoy', 'vikhorevka', 'san jeronimo', 'luderitz', 'ewa beach', 'ahipara', 'lulea', 'opuwo', 'attawapiskat', 'touros', 'sungaipenuh', 'nizhneyansk', 'menongue', 'deulgaon raja', 'mbandaka', 'mtwara', 'kashi', 'bundaberg', 'saint-augustin', 'bokoro', 'vaitupu', 'lompoc', 'sabha', 'airai', 'la gomera', 'impfondo', 'timizart', 'san policarpo', 'bubaque', 'iquique', 'elban', 'sault sainte marie', 'pedro juan caballero', 'swarzedz', 'chagda', 'severo-kurilsk', 'coihaique', 'buala', 'teya', 'rawson', 'tabialan', 'kieta', 'port elizabeth', 'sao jose da coroa grande', 'moberly', 'geraldton', 'campos altos', 'umkomaas', 'hualmay', 'dillon', 'novobirilyussy', 'clinton', 'galle', 'sokolo', 'gvarv', 'phalodi', 'marsabit', 'bathsheba', 'mikhaylovka', 'noumea', 'tongliao', 'college', 'sao gabriel da cachoeira', 'port keats', 'kiama', 'kiunga', 'coahuayana', 'morros', 'lucapa', 'prince rupert', 'eureka', 'chermoz', 'huambo', 'eskasem', 'meulaboh', 'mporokoso', 'foumban', 'torres', 'talnakh', 'the valley', 'tuktoyaktuk', 'sao joao da barra', 'haines junction', 'awbari', 'tabuk', 'bontang', 'richards bay', 'co ...

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL and API key
url = "https://api.openweathermap.org/data/2.5/weather"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?appid={weather_api_key}&units=imperial&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Latitude": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | nome
# Processing Record 7 of Set 1 | bowen
# Processing Record 8 of Set 1 | mercedes
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | lazarev
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | bengkulu
# Processing Record 15 of Set 1 | provideniya
# Processing Record 16 of Set 1 | avera
# Processing Record 17 of Set 1 | bolgar
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | bethanien
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | karratha
# Processing Record 23 of Set 1 | si sa ket
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | formosa
# Processing Record 27 of Set 1 | chokurdakh
# Processing Record 28 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 1 | grindavik
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | te anau
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | troitsko-pechorsk
# Processing Record 35 of Set 1 | diapaga
# Processing Record 36 of Set 1 | yulara
# Processing Record 37 of Set 1 | okhotsk
# Processing Record 38 of Set 1 | doka
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | hasaki
# Processing Record 41 of Set 1 | cap malheureux
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | nanortalik
# Processing Record 44 of Set 1 | asfi
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | ostersund
# Processing Record 48 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 1 | urumqi
# Processing Record 50 of Set 1 | hermanus
# Processing Record 0 of Set 2 | ribeira grande
# Processing Record 1 of Set 2 | alekseyevsk
# Processing Record 2 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | kavieng
# Processing Record 6 of Set 2 | okha
# Processing Record 7 of Set 2 | iqaluit
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | bauchi
# Processing Record 10 of Set 2 | cherskiy
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | dikson
# Processing Record 13 of Set 2 | gasa
# Processing Record 14 of Set 2 | marsh harbour
# Processing Record 15 of Set 2 | ponta delgada
# Processing Record 16 of Set 2 | calvillo
# Processing Record 17 of Set 2 | adjumani
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | rikitea
# Processing Record 20 of Set 2 | vila velha
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | ntoum
# Processing Record 25 of Set 2 | arlit
# Processing Record 26 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | shevchenkove
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | ambon
# Processing Record 31 of Set 2 | ksenyevka
# City not found. Skipping...
# Processing Record 32 of Set 2 | mul
# Processing Record 33 of Set 2 | brigantine
# Processing Record 34 of Set 2 | queenstown
# Processing Record 35 of Set 2 | kaitangata
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | chiredzi
# Processing Record 38 of Set 2 | broome
# Processing Record 39 of Set 2 | aykhal
# Processing Record 40 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 2 | mayumba
# Processing Record 44 of Set 2 | bambous virieux
# Processing Record 45 of Set 2 | zhigansk
# Processing Record 46 of Set 2 | saquarema
# Processing Record 47 of Set 2 | bandarbeyla
# Processing Record 48 of Set 2 | concord
# Processing Record 49 of Set 2 | santa rosa
# Processing Record 0 of Set 3 | xining
# Processing Record 1 of Set 3 | kitgum
# Processing Record 2 of Set 3 | kodiak
# Processing Record 3 of Set 3 | constitucion
# Processing Record 4 of Set 3 | olinda
# Processing Record 5 of Set 3 | aksay
# Processing Record 6 of Set 3 | poum
# Processing Record 7 of Set 3 | egvekinot
# Processing Record 8 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 3 | puerto ayora
# Processing Record 10 of Set 3 | kununurra
# Processing Record 11 of Set 3 | strai
# Processing Record 12 of Set 3 | northam
# Processing Record 13 of Set 3 | saldanha
# Processing Record 14 of Set 3 | cuamba
# Processing Record 15 of Set 3 | sao jose de ribamar
# Processing Record 16 of Set 3 | san jose
# Processing Record 17 of Set 3 | mehamn
# Processing Record 18 of Set 3 | san rafael del sur
# Processing Record 19 of Set 3 | sitka
# Processing Record 20 of Set 3 | katsuura
# Processing Record 21 of Set 3 | mujiayingzi
# Processing Record 22 of Set 3 | comodoro rivadavia
# Processing Record 23 of Set 3 | mar del plata
# Processing Record 24 of Set 3 | bull savanna
# Processing Record 25 of Set 3 | mahebourg
# Processing Record 26 of Set 3 | saurimo
# Processing Record 27 of Set 3 | fort nelson
# Processing Record 28 of Set 3 | mahibadhoo
# Processing Record 29 of Set 3 | barrow
# Processing Record 30 of Set 3 | olafsvik
# Processing Record 31 of Set 3 | borogontsy
# Processing Record 32 of Set 3 | hit
# Processing Record 33 of Set 3 | vestmannaeyjar
# Processing Record 34 of Set 3 | aybak
# City not found. Skipping...
# Processing Record 35 of Set 3 | qaanaaq
# Processing Record 36 of Set 3 | calamar
# Processing Record 37 of Set 3 | narsaq
# Processing Record 38 of Set 3 | jefferson city
# Processing Record 39 of Set 3 | tumut
# Processing Record 40 of Set 3 | lagoa
# Processing Record 41 of Set 3 | seoul
# Processing Record 42 of Set 3 | baoding
# Processing Record 43 of Set 3 | gat
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | serenje
# Processing Record 46 of Set 3 | that phanom
# Processing Record 47 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 3 | port lincoln
# Processing Record 0 of Set 4 | tungkang
# City not found. Skipping...
# Processing Record 1 of Set 4 | tigil
# Processing Record 2 of Set 4 | alta floresta
# Processing Record 3 of Set 4 | chuy
# Processing Record 4 of Set 4 | karymskoye
# Processing Record 5 of Set 4 | port blair
# Processing Record 6 of Set 4 | norman wells
# Processing Record 7 of Set 4 | carnarvon
# Processing Record 8 of Set 4 | rocha
# Processing Record 9 of Set 4 | tars
# Processing Record 10 of Set 4 | moralillo
# Processing Record 11 of Set 4 | ashland
# Processing Record 12 of Set 4 | surt
# Processing Record 13 of Set 4 | hofn
# Processing Record 14 of Set 4 | phalaborwa
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | bargi
# Processing Record 17 of Set 4 | nuuk
# Processing Record 18 of Set 4 | wanning
# Processing Record 19 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 20 of Set 4 | fasa
# Processing Record 21 of Set 4 | chumphon
# Processing Record 22 of Set 4 | san luis
# Processing Record 23 of Set 4 | port macquarie
# Processing Record 24 of Set 4 | tromso
# Processing Record 25 of Set 4 | mackay
# Processing Record 26 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 4 | vysokogornyy
# Processing Record 28 of Set 4 | jambi
# Processing Record 29 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 4 | agua branca
# Processing Record 31 of Set 4 | khatanga
# Processing Record 32 of Set 4 | port alfred
# Processing Record 33 of Set 4 | moron
# Processing Record 34 of Set 4 | bonavista
# Processing Record 35 of Set 4 | jalu
# Processing Record 36 of Set 4 | alibag
# Processing Record 37 of Set 4 | champerico
# Processing Record 38 of Set 4 | igurusi
# Processing Record 39 of Set 4 | naze
# Processing Record 40 of Set 4 | sekoma
# Processing Record 41 of Set 4 | moindou
# Processing Record 42 of Set 4 | atasu
# Processing Record 43 of Set 4 | quatre cocos
# Processing Record 44 of Set 4 | vardo
# Processing Record 45 of Set 4 | keshan
# City not found. Skipping...
# Processing Record 46 of Set 4 | namibe
# Processing Record 47 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 4 | mayo
# Processing Record 49 of Set 4 | lagos
# Processing Record 0 of Set 5 | ondjiva
# Processing Record 1 of Set 5 | corralillo
# Processing Record 2 of Set 5 | oriximina
# Processing Record 3 of Set 5 | santa rosalia
# Processing Record 4 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 5 of Set 5 | verkhnevilyuysk
# Processing Record 6 of Set 5 | kahului
# Processing Record 7 of Set 5 | vao
# Processing Record 8 of Set 5 | hohhot
# Processing Record 9 of Set 5 | ulladulla
# Processing Record 10 of Set 5 | aksu
# Processing Record 11 of Set 5 | birecik
# Processing Record 12 of Set 5 | komsomolskiy
# Processing Record 13 of Set 5 | sinop
# Processing Record 14 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 5 | hamilton
# Processing Record 16 of Set 5 | xai-xai
# Processing Record 17 of Set 5 | dno
# Processing Record 18 of Set 5 | borovskoy
# Processing Record 19 of Set 5 | codrington
# Processing Record 20 of Set 5 | salalah
# Processing Record 21 of Set 5 | kenai
# Processing Record 22 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 5 | san patricio
# Processing Record 24 of Set 5 | flinders
# Processing Record 25 of Set 5 | izhma
# Processing Record 26 of Set 5 | berdyuzhye
# City not found. Skipping...
# Processing Record 27 of Set 5 | oranjemund
# Processing Record 28 of Set 5 | kudahuvadhoo
# Processing Record 29 of Set 5 | kaeo
# Processing Record 30 of Set 5 | cabo san lucas
# Processing Record 31 of Set 5 | sola
# Processing Record 32 of Set 5 | westport
# Processing Record 33 of Set 5 | itaueira
# Processing Record 34 of Set 5 | saint-philippe
# Processing Record 35 of Set 5 | brandfort
# Processing Record 36 of Set 5 | ostrovnoy
# Processing Record 37 of Set 5 | vikhorevka
# Processing Record 38 of Set 5 | san jeronimo
# Processing Record 39 of Set 5 | luderitz
# Processing Record 40 of Set 5 | ewa beach
# Processing Record 41 of Set 5 | ahipara
# Processing Record 42 of Set 5 | lulea
# Processing Record 43 of Set 5 | opuwo
# Processing Record 44 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 5 | touros
# Processing Record 46 of Set 5 | sungaipenuh
# Processing Record 47 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 5 | menongue
# Processing Record 49 of Set 5 | deulgaon raja
# Processing Record 0 of Set 6 | mbandaka
# Processing Record 1 of Set 6 | mtwara
# Processing Record 2 of Set 6 | kashi
# Processing Record 3 of Set 6 | bundaberg
# Processing Record 4 of Set 6 | saint-augustin
# Processing Record 5 of Set 6 | bokoro
# Processing Record 6 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 6 | lompoc
# Processing Record 8 of Set 6 | sabha
# Processing Record 9 of Set 6 | airai
# Processing Record 10 of Set 6 | la gomera
# Processing Record 11 of Set 6 | impfondo
# Processing Record 12 of Set 6 | timizart
# Processing Record 13 of Set 6 | san policarpo
# Processing Record 14 of Set 6 | bubaque
# Processing Record 15 of Set 6 | iquique
# Processing Record 16 of Set 6 | elban
# Processing Record 17 of Set 6 | sault sainte marie
# Processing Record 18 of Set 6 | pedro juan caballero
# Processing Record 19 of Set 6 | swarzedz
# Processing Record 20 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 6 | severo-kurilsk
# Processing Record 22 of Set 6 | coihaique
# Processing Record 23 of Set 6 | buala
# Processing Record 24 of Set 6 | teya
# Processing Record 25 of Set 6 | rawson
# Processing Record 26 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 27 of Set 6 | kieta
# Processing Record 28 of Set 6 | port elizabeth
# Processing Record 29 of Set 6 | sao jose da coroa grande
# Processing Record 30 of Set 6 | moberly
# Processing Record 31 of Set 6 | geraldton
# Processing Record 32 of Set 6 | campos altos
# Processing Record 33 of Set 6 | umkomaas
# Processing Record 34 of Set 6 | hualmay
# Processing Record 35 of Set 6 | dillon
# Processing Record 36 of Set 6 | novobirilyussy
# Processing Record 37 of Set 6 | clinton
# Processing Record 38 of Set 6 | galle
# Processing Record 39 of Set 6 | sokolo
# Processing Record 40 of Set 6 | gvarv
# Processing Record 41 of Set 6 | phalodi
# Processing Record 42 of Set 6 | marsabit
# Processing Record 43 of Set 6 | bathsheba
# Processing Record 44 of Set 6 | mikhaylovka
# Processing Record 45 of Set 6 | noumea
# Processing Record 46 of Set 6 | tongliao
# Processing Record 47 of Set 6 | college
# Processing Record 48 of Set 6 | sao gabriel da cachoeira
# Processing Record 49 of Set 6 | port keats
# Processing Record 0 of Set 7 | kiama
# Processing Record 1 of Set 7 | kiunga
# Processing Record 2 of Set 7 | coahuayana
# Processing Record 3 of Set 7 | morros
# Processing Record 4 of Set 7 | lucapa
# Processing Record 5 of Set 7 | prince rupert
# Processing Record 6 of Set 7 | eureka
# Processing Record 7 of Set 7 | chermoz
# Processing Record 8 of Set 7 | huambo
# Processing Record 9 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 10 of Set 7 | meulaboh
# Processing Record 11 of Set 7 | mporokoso
# Processing Record 12 of Set 7 | foumban
# Processing Record 13 of Set 7 | torres
# Processing Record 14 of Set 7 | talnakh
# Processing Record 15 of Set 7 | the valley
# Processing Record 16 of Set 7 | tuktoyaktuk
# Processing Record 17 of Set 7 | sao joao da barra
# Processing Record 18 of Set 7 | haines junction
# Processing Record 19 of Set 7 | awbari
# Processing Record 20 of Set 7 | tabuk
# Processing Record 21 of Set 7 | bontang
# Processing Record 22 of Set 7 | richards bay
# Processing Record 23 of Set 7 | coxim
# Processing Record 24 of Set 7 | valdivia
# Processing Record 25 of Set 7 | aasiaat
# Processing Record 26 of Set 7 | la maddalena
# Processing Record 27 of Set 7 | bure
# Processing Record 28 of Set 7 | clyde river
# Processing Record 29 of Set 7 | bayeux
# Processing Record 30 of Set 7 | karlskrona
# Processing Record 31 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 7 | faanui
# Processing Record 33 of Set 7 | aripuana
# Processing Record 34 of Set 7 | lindi
# Processing Record 35 of Set 7 | yumen
# Processing Record 36 of Set 7 | port augusta
# Processing Record 37 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 7 | tongchuan
# Processing Record 39 of Set 7 | samarai
# Processing Record 40 of Set 7 | ormara
# Processing Record 41 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 7 | ust-tsilma
# Processing Record 44 of Set 7 | altagracia de orituco
# Processing Record 45 of Set 7 | marrakesh
# Processing Record 46 of Set 7 | owase
# Processing Record 47 of Set 7 | carutapera
# Processing Record 48 of Set 7 | beloha
# Processing Record 49 of Set 7 | ugoofaaru
# Processing Record 0 of Set 8 | labuhan
# Processing Record 1 of Set 8 | cayenne
# Processing Record 2 of Set 8 | vanavara
# Processing Record 3 of Set 8 | dumas
# Processing Record 4 of Set 8 | manaure
# Processing Record 5 of Set 8 | byron bay
# Processing Record 6 of Set 8 | darovskoy
# Processing Record 7 of Set 8 | macheng
# Processing Record 8 of Set 8 | marawi
# Processing Record 9 of Set 8 | sovetskiy
# Processing Record 10 of Set 8 | normandin
# Processing Record 11 of Set 8 | gulshat
# City not found. Skipping...
# Processing Record 12 of Set 8 | padang
# Processing Record 13 of Set 8 | milingimbi
# City not found. Skipping...
# Processing Record 14 of Set 8 | asosa
# Processing Record 15 of Set 8 | kutum
# Processing Record 16 of Set 8 | manadhoo
# Processing Record 17 of Set 8 | washougal
# Processing Record 18 of Set 8 | ji-parana
# City not found. Skipping...
# Processing Record 19 of Set 8 | tadine
# Processing Record 20 of Set 8 | leh
# Processing Record 21 of Set 8 | sinnamary
# Processing Record 22 of Set 8 | sept-iles
# Processing Record 23 of Set 8 | labuan
# Processing Record 24 of Set 8 | antalaha
# Processing Record 25 of Set 8 | kavaratti
# Processing Record 26 of Set 8 | souillac
# Processing Record 27 of Set 8 | veraval
# Processing Record 28 of Set 8 | forest grove
# Processing Record 29 of Set 8 | berlevag
# Processing Record 30 of Set 8 | sydney
# Processing Record 31 of Set 8 | omboue
# Processing Record 32 of Set 8 | walvis bay
# Processing Record 33 of Set 8 | vila franca do campo
# Processing Record 34 of Set 8 | upernavik
# Processing Record 35 of Set 8 | blythe
# Processing Record 36 of Set 8 | dauphin
# Processing Record 37 of Set 8 | pestretsy
# Processing Record 38 of Set 8 | buzmeyin
# Processing Record 39 of Set 8 | bambari
# Processing Record 40 of Set 8 | ust-kut
# Processing Record 41 of Set 8 | balabac
# Processing Record 42 of Set 8 | manta
# Processing Record 43 of Set 8 | aklavik
# Processing Record 44 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 45 of Set 8 | ferme-neuve
# Processing Record 46 of Set 8 | isangel
# Processing Record 47 of Set 8 | laives
# Processing Record 48 of Set 8 | kaseda
# Processing Record 49 of Set 8 | kupang
# Processing Record 0 of Set 9 | umm lajj
# Processing Record 1 of Set 9 | nyurba
# Processing Record 2 of Set 9 | petropavlovka
# Processing Record 3 of Set 9 | vanimo
# Processing Record 4 of Set 9 | xinmin
# Processing Record 5 of Set 9 | dingle
# Processing Record 6 of Set 9 | forio
# Processing Record 7 of Set 9 | marsa matruh
# Processing Record 8 of Set 9 | atar
# Processing Record 9 of Set 9 | warmbad
# Processing Record 10 of Set 9 | saint anthony
# Processing Record 11 of Set 9 | paraiso
# Processing Record 12 of Set 9 | maningrida
# Processing Record 13 of Set 9 | portland
# Processing Record 14 of Set 9 | isla vista
# Processing Record 15 of Set 9 | lavrentiya
# Processing Record 16 of Set 9 | svetlogorsk
# Processing Record 17 of Set 9 | buncrana
# Processing Record 18 of Set 9 | longyearbyen
# Processing Record 19 of Set 9 | kushmurun
# Processing Record 20 of Set 9 | lata
# Processing Record 21 of Set 9 | srednekolymsk
# Processing Record 22 of Set 9 | batemans bay
# Processing Record 23 of Set 9 | nieves
# Processing Record 24 of Set 9 | esmeralda
# Processing Record 25 of Set 9 | muroto
# Processing Record 26 of Set 9 | belaya gora
# Processing Record 27 of Set 9 | nantucket
# Processing Record 28 of Set 9 | amahai
# Processing Record 29 of Set 9 | safaga
# Processing Record 30 of Set 9 | twin falls
# Processing Record 31 of Set 9 | chapais
# Processing Record 32 of Set 9 | ilulissat
# Processing Record 33 of Set 9 | sechura
# Processing Record 34 of Set 9 | bandar-e lengeh
# Processing Record 35 of Set 9 | timberlake
# Processing Record 36 of Set 9 | alofi
# Processing Record 37 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 9 | ilhabela
# Processing Record 39 of Set 9 | muros
# Processing Record 40 of Set 9 | joshimath
# Processing Record 41 of Set 9 | berasia
# Processing Record 42 of Set 9 | mecca
# Processing Record 43 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 9 | ola
# Processing Record 45 of Set 9 | luena
# Processing Record 46 of Set 9 | buraydah
# Processing Record 47 of Set 9 | siddapur
# Processing Record 48 of Set 9 | colares
# Processing Record 49 of Set 9 | san rafael
# Processing Record 0 of Set 10 | janauba
# Processing Record 1 of Set 10 | boyolangu
# Processing Record 2 of Set 10 | acarau
# Processing Record 3 of Set 10 | dumai
# Processing Record 4 of Set 10 | hami
# Processing Record 5 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 10 | jinzhou
# Processing Record 7 of Set 10 | ust-nera
# Processing Record 8 of Set 10 | gazojak
# Processing Record 9 of Set 10 | bilma
# Processing Record 10 of Set 10 | serpa
# Processing Record 11 of Set 10 | huilong
# Processing Record 12 of Set 10 | tilichiki
# Processing Record 13 of Set 10 | harper
# Processing Record 14 of Set 10 | seydi
# Processing Record 15 of Set 10 | anadyr
# Processing Record 16 of Set 10 | san quintin
# Processing Record 17 of Set 10 | karakol
# Processing Record 18 of Set 10 | henties bay
# Processing Record 19 of Set 10 | boa vista
# Processing Record 20 of Set 10 | koppies
# Processing Record 21 of Set 10 | chara
# Processing Record 22 of Set 10 | garowe
# Processing Record 23 of Set 10 | capaci
# Processing Record 24 of Set 10 | yangambi
# Processing Record 25 of Set 10 | grand gaube
# Processing Record 26 of Set 10 | dharchula
# Processing Record 27 of Set 10 | garissa
# Processing Record 28 of Set 10 | coquimbo
# Processing Record 29 of Set 10 | sydney mines
# Processing Record 30 of Set 10 | paamiut
# Processing Record 31 of Set 10 | mattru
# Processing Record 32 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 10 | visby
# Processing Record 34 of Set 10 | baykit
# Processing Record 35 of Set 10 | tsiroanomandidy
# Processing Record 36 of Set 10 | lasa
# Processing Record 37 of Set 10 | atambua
# Processing Record 38 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 39 of Set 10 | udobnaya
# Processing Record 40 of Set 10 | minsk
# Processing Record 41 of Set 10 | chupa
# Processing Record 42 of Set 10 | batagay-alyta
# Processing Record 43 of Set 10 | barreirinha
# Processing Record 44 of Set 10 | maloy
# Processing Record 45 of Set 10 | lakheri
# Processing Record 46 of Set 10 | rivera
# Processing Record 47 of Set 10 | pomabamba
# Processing Record 48 of Set 10 | oktyabrskoye
# Processing Record 49 of Set 10 | banjar
# Processing Record 0 of Set 11 | wuning
# Processing Record 1 of Set 11 | thanh hoa
# Processing Record 2 of Set 11 | duz
# City not found. Skipping...
# Processing Record 3 of Set 11 | spornoye
# Processing Record 4 of Set 11 | lufkin
# Processing Record 5 of Set 11 | russell
# Processing Record 6 of Set 11 | nosy varika
# Processing Record 7 of Set 11 | sioux lookout
# Processing Record 8 of Set 11 | bulalacao
# Processing Record 9 of Set 11 | matucana
# Processing Record 10 of Set 11 | upata
# Processing Record 11 of Set 11 | watertown
# Processing Record 12 of Set 11 | burica
# City not found. Skipping...
# Processing Record 13 of Set 11 | agropoli
# Processing Record 14 of Set 11 | havre-saint-pierre
# Processing Record 15 of Set 11 | kasama
# Processing Record 16 of Set 11 | chifeng
# Processing Record 17 of Set 11 | caravelas
# Processing Record 18 of Set 11 | mlonggo
# Processing Record 19 of Set 11 | chirongui
# Processing Record 20 of Set 11 | loiza
# Processing Record 21 of Set 11 | kalomo
# City not found. Skipping...
# Processing Record 22 of Set 11 | concepcion
# Processing Record 23 of Set 11 | beringovskiy
# Processing Record 24 of Set 11 | rumoi
# Processing Record 25 of Set 11 | teknaf
# Processing Record 26 of Set 11 | dombas
# Processing Record 27 of Set 11 | sangar
# Processing Record 28 of Set 11 | fortuna
# Processing Record 29 of Set 11 | pangnirtung
# Processing Record 30 of Set 11 | bad hofgastein
# Processing Record 31 of Set 11 | puri
# Processing Record 32 of Set 11 | yar-sale
# Processing Record 33 of Set 11 | arman
# Processing Record 34 of Set 11 | cacu
# Processing Record 35 of Set 11 | hukuntsi
# Processing Record 36 of Set 11 | kirakira
# Processing Record 37 of Set 11 | newport
# Processing Record 38 of Set 11 | cairns
# Processing Record 39 of Set 11 | whitehorse
# Processing Record 40 of Set 11 | yinchuan
# Processing Record 41 of Set 11 | sorong
# Processing Record 42 of Set 11 | nouakchott
# Processing Record 43 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 44 of Set 11 | bani walid
# Processing Record 45 of Set 11 | wajir
# Processing Record 46 of Set 11 | nola
# Processing Record 47 of Set 11 | guerrero negro
# Processing Record 48 of Set 11 | wazzan
# City not found. Skipping...
# Processing Record 49 of Set 11 | chicama
# Processing Record 0 of Set 12 | tazovskiy
# Processing Record 1 of Set 12 | san juan de flores
# Processing Record 2 of Set 12 | middelburg
# Processing Record 3 of Set 12 | victoria
# Processing Record 4 of Set 12 | olesnica
# Processing Record 5 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 6 of Set 12 | sai buri
# Processing Record 7 of Set 12 | kaifeng
# Processing Record 8 of Set 12 | turayf
# Processing Record 9 of Set 12 | auki
# Processing Record 10 of Set 12 | evensk
# Processing Record 11 of Set 12 | charters towers
# Processing Record 12 of Set 12 | port moresby
# Processing Record 13 of Set 12 | tautira
# Processing Record 14 of Set 12 | tlahualilo
# City not found. Skipping...
# Processing Record 15 of Set 12 | lamar
# Processing Record 16 of Set 12 | deputatskiy
# Processing Record 17 of Set 12 | mount gambier
# Processing Record 18 of Set 12 | cam ranh
# Processing Record 19 of Set 12 | nagua
# Processing Record 20 of Set 12 | otavi
# Processing Record 21 of Set 12 | seguela
# Processing Record 22 of Set 12 | namatanai
# Processing Record 23 of Set 12 | mandalgovi
# Processing Record 24 of Set 12 | rio grande
# Processing Record 25 of Set 12 | wetaskiwin
# Processing Record 26 of Set 12 | alihe
# Processing Record 27 of Set 12 | sobolevo
# Processing Record 28 of Set 12 | aitape
# Processing Record 29 of Set 12 | san carlos del zulia
# Processing Record 30 of Set 12 | freeport
# Processing Record 31 of Set 12 | narbonne
# Processing Record 32 of Set 12 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 33 of Set 12 | tayoltita
# Processing Record 34 of Set 12 | inuvik
# Processing Record 35 of Set 12 | kulhudhuffushi
# Processing Record 36 of Set 12 | lithakia
# Processing Record 37 of Set 12 | zheleznodorozhnyy
# Processing Record 38 of Set 12 | cahors
# Processing Record 39 of Set 12 | inirida
# Processing Record 40 of Set 12 | hagere selam
# Processing Record 41 of Set 12 | saint george
# Processing Record 42 of Set 12 | remanso
# Processing Record 43 of Set 12 | charleston
# Processing Record 44 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 46 of Set 12 | sisimiut
# Processing Record 47 of Set 12 | manokwari
# Processing Record 48 of Set 12 | lisakovsk
# Processing Record 49 of Set 12 | necocli
# Processing Record 0 of Set 13 | shakawe
# Processing Record 1 of Set 13 | kachkanar
# Processing Record 2 of Set 13 | plum
# Processing Record 3 of Set 13 | muisne
# Processing Record 4 of Set 13 | fort collins
# Processing Record 5 of Set 13 | andenes
# Processing Record 6 of Set 13 | canutama
# Processing Record 7 of Set 13 | palu
# Processing Record 8 of Set 13 | roald
# Processing Record 9 of Set 13 | tungor
# Processing Record 10 of Set 13 | hannibal
# Processing Record 11 of Set 13 | nadym
# Processing Record 12 of Set 13 | porto walter
# Processing Record 13 of Set 13 | waipawa
# Processing Record 14 of Set 13 | watrous
# Processing Record 15 of Set 13 | pevek
# Processing Record 16 of Set 13 | makakilo city
# Processing Record 17 of Set 13 | jamame
# Processing Record 18 of Set 13 | mount isa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
print(city_data_df.count())
# Out:
# City          568
# Latitude      568
# Lng           568
# Max Temp      568
# Humidity      568
# Cloudiness    568
# Wind Speed    568
# Country       568
# Date          568
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City  Latitude       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  busselton  -33.6500  115.3333     64.40        57          17       13.73
# 1     hobart  -42.8794  147.3294     63.27        93          45        2.84
# 2  jamestown   42.0970  -79.2353     39.02        65           0        3.44
# 3   tasiilaq   65.6145  -37.6368      8.76        65           0        6.64
# 4       nome   64.5011 -165.4064     18.16        86          75       16.11
#
#   Country        Date
# 0      AU  1680050034
# 1      AU  1680050034
# 2      US  1680050034
# 3      GL  1680050034
# 4      US  1680050035

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City  Latitude       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        busselton  -33.6500  115.3333     64.40        57          17
# 1           hobart  -42.8794  147.3294     63.27        93          45
# 2        jamestown   42.0970  -79.2353     39.02        65           0
# 3         tasiilaq   65.6145  -37.6368      8.76        65           0
# 4             nome   64.5011 -165.4064     18.16        86          75
#
#          Wind Speed Country        Date
# City_ID
# 0             13.73      AU  1680050034
# 1              2.84      AU  1680050034
# 2              3.44      US  1680050034
# 3              6.64      GL  1680050034
# 4             16.11      US  1680050035

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat_temp_df = city_data_df[["Latitude", "Max Temp"]].astype(float)
lat_temp_df.plot(
    kind="scatter", 
    x="Latitude", 
    y="Max Temp",


# Incorporate the other graph properties
    title="City Max Latitude vs. Temperature(2022-10-18)",
    ylabel="Max Temprature (C)",
    grid=True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity

lat_hum_df = city_data_df[["Latitude","Humidity"]].astype(float)
lat_hum_df.plot(
    kind="scatter", 
    x="Latitude", 
    y="Humidity",

# Incorporate the other graph properties
    title="City Max Latitude vs. Humidity (2022-10-18)",
    ylabel="Humidity(%)",
    grid=True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat_cloud_df = city_data_df[["Latitude","Cloudiness"]].astype(float)
lat_cloud_df.plot(
    kind="scatter", 
    x="Latitude", 
    y="Cloudiness",

# Incorporate the other graph properties
    title="City Max Latitude vs. Cloudiness (2022-10-18)",
    ylabel="Cloudiness(%)",
    grid=True)
# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lat_wind_df = city_data_df[["Latitude","Wind Speed"]].astype(float)
lat_wind_df.plot(
    kind="scatter", 
    x="Latitude", 
    y="Wind Speed",

# Incorporate the other graph properties
    title="City Max Latitude vs. Wind Speed (2022-10-18)",
    ylabel="Wind Speed (m/s)",
    grid=True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df.loc[(city_data_df["Latitude"]>=0),:]

# Display sample data
northern_hemi_df.head()
# Out:
#               City  Latitude       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        jamestown   42.0970  -79.2353     39.02        65           0
# 3         tasiilaq   65.6145  -37.6368      8.76        65           0
# 4             nome   64.5011 -165.4064     18.16        86          75
# 9          lazarev   52.2250  141.5131     31.26        80          90
# 10            hilo   19.7297 -155.0900     79.95        80         100
#
#          Wind Speed Country        Date
# City_ID
# 2              3.44      US  1680050034
# 3              6.64      GL  1680050034
# 4             16.11      US  1680050035
# 9             14.14      RU  1680050035
# 10            13.80      US  1680050036

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[(city_data_df["Latitude"]<0),:]

# Display sample data
southern_hemi_df.head()
# Out:
#               City  Latitude       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        busselton  -33.6500  115.3333     64.40        57          17
# 1           hobart  -42.8794  147.3294     63.27        93          45
# 5            bowen  -20.0167  148.2333     87.04        56          25
# 6         mercedes  -34.6515  -59.4307     72.86        65           0
# 7             lebu  -37.6167  -73.6500     52.84        79           4
#
#          Wind Speed Country        Date
# City_ID
# 0             13.73      AU  1680050034
# 1              2.84      AU  1680050034
# 5              7.83      AU  1680050035
# 6              9.78      AR  1680050035
# 7              2.86      CL  1680050035

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Latitude"].astype("float")
y_values = northern_hemi_df["Max Temp"].astype("float")


plt.scatter(x_values,y_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xq/xdbqztz92zs24q39hvzwj65m0000gn/T/ipykernel_15916/1190603494.py in <module>
#       2 x_values = northern_hemi_df["Latitude"].astype("float")
#       3 y_values = northern_hemi_df["Max Temp"].astype("float")
# ----> 4 linear_regression_plot(x_values, y_values, title="Latitude vs Max Temp", x_label="Latitude", y_label="Max Temp")
#       5
#       6
#
# NameError: name 'linear_regression_plot' is not defined

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
